# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

audioFile = './AudiosComandosVoz/Cocina/Apagar/audio (1).wav'

signal, sr = librosa.load(audioFile)

print(signal.shape)

mfccs = librosa.feature.mfcc(y=signal, n_mfcc=13, sr=sr)

print(mfccs.shape)

plt.figure(figsize=(25,10))
librosa.display.specshow(mfccs,x_axis="time",sr=sr)
plt.colorbar(format="%+2.f")
plt.show()
# Out:
# (26854,)
# (13, 53)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 17
#      15 plt.figure(figsize=(25,10))
#      16 librosa.display.specshow(mfccs,x_axis="time",sr=sr)
# ---> 17 plt.colorbar(format="%+2.f")
#      18 plt.show()
#
# File c:\Users\marko\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2137, in colorbar(mappable, cax, ax, **kwargs)
#    2132     if mappable is None:
#    2133         raise RuntimeError('No mappable was found to use for colorbar '
#    2134                            'creation. First define a mappable such as '
#    2135                            'an image (with imshow) or a contour set ('
#    2136                            'with contourf).')
# -> 2137 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2138 return ret
#
# File c:\Users\marko\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:1279, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1276 current_ax = self.gca()
#    1277 userax = False
#    1278 if (use_gridspec
# -> 1279         and isinstance(ax, mpl.axes._base._AxesBase)
#    1280         and ax.get_subplotspec()):
#    1281     cax, kwargs = cbar.make_axes_gridspec(ax, **kwargs)
#    1282 else:
#
# File c:\Users\marko\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'axes'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib_inline\backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File c:\Users\marko\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
